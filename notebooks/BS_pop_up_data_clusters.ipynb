# %% [markdown]
# ## Below the rough outlines for the datacluster
# In this notebook the first attempt to make a dataset that is dynamic in time is made.
# The data set has to be dynamic in the way that over time the chance that a certain datapoint pops up in a cluster shifts between the clusters.

# %% [markdown]
# #### import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Make first a X amount of clusters in the 2d space to generate strong clusters.

# %%
def cluster_centers(N_clusters):
    coordinates = []
    for i in range(N_clusters):
        x = np.random.uniform(0,100)
        y = np.random.uniform(0,100)
        coordinates.append([int(i), x,y])
    coordinates = np.array(coordinates)
    return coordinates

# %%
centers = cluster_centers(6)

# %%
df = pd.DataFrame(centers, columns={'x', 'y', 'cluster_name'})
df.plot(kind='scatter', x='x', y='y')

# %%
df
# Out:
#    cluster_name          x          y
# 0           0.0  37.432034  53.059608
# 1           1.0  39.619180  57.122616
# 2           2.0  65.635658  13.749038
# 3           3.0  54.151982  70.172493
# 4           4.0  66.958757  15.433416
# 5           5.0  62.265308  87.161521

# %% [markdown]
# Generate datapoints around the cluster centers

# %%
def select_cluster_randomly(time, centers, p_start):
    probabilities = p_start
    for i in range(len(centers)):
        np.sin(2*np.pi*time)**2
    return np.random.choice(centers.T[2], p=probabilities)
    


def generate_points_in_cluster(time, centers):
    x = centers.T[0]
    y = centers.T[1]

# %%
np.random.choice(centers.T[2], size=20, p=[0.1, 0.5, 0.1, 0.1, 0.1, 0.1])
# Out:
# array([1., 0., 0., 1., 3., 2., 1., 1., 1., 5., 2., 1., 1., 1., 4., 1., 1.,
#        4., 2., 3.])

# %%
plt.plot(np.sin(np.arange(0,100,0.01))**2)
plt.plot(np.sin(np.arange(0,100,0.01)+np.pi*0.5)**2)

# %%
plt.plot((np.sin(np.arange(0,100,0.01)+np.pi*0.5)**2+np.sin(np.arange(0,100,0.01))**2))

# %%
a = np.sin(np.arange(0,100,0.01)+np.pi*0.5)**2+np.sin(np.arange(0,100,0.01))**2

# %%
plt.plot(a)
