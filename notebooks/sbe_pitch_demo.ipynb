# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from olac import data_generators
from olac import vis
from olac import popping_clusters as pop

from keras.models import Sequential
from keras.layers import Dense
import keras.layers as ly
# %matplotlib inline
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = Sequential()
model.add(ly.Dense(units=2, activation='relu', input_dim=2))
model.add(ly.Dense(units=6, activation='relu'))
model.add(ly.Dense(units=12, activation='relu'))
model.add(ly.Dense(units=6, activation='relu'))
model.add(ly.Dense(units=1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
vis.main(model, data_generators.roving_balls, 'accuracy', steps=2000, p_train=10, window=5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-bdb3b9a36c98> in <module>()
# ----> 1 vis.main(model, data_generators.roving_balls, 'accuracy', steps=2000, p_train=10, window=5)
#
# ~/Documents/Projecten/JADS/olac/olac/olac/vis.py in main(MODEL, GENERATOR, metric, weights, window, p_train, **kwargs)
#     283
#     284         plt.figure(figsize=(20, 10))
# --> 285         plt.subplot(121)
#     286         plt.plot(np.arange(0, len(metric_in_time)), metric_in_time)
#     287         plt.xlim(0, int(len(np.arange(1, itrs, int(wndw/4)))))
#
# ~/.pyenv/versions/3.6.5/envs/olac_project/lib/python3.6/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1048
#    1049     fig = gcf()
# -> 1050     a = fig.add_subplot(*args, **kwargs)
#    1051     bbox = a.bbox
#    1052     byebye = []
#
# ...
