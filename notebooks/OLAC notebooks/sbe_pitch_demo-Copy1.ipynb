# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from olac import data_generators
from olac import vis

from keras.models import Sequential
from keras.layers import Dense
import keras.layers as ly
# %matplotlib inline
# %load_ext autoreload

# %autoreload 2
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(ly.Dense(units=2, activation='relu', input_dim=2))
model.add(ly.Dense(units=6, activation='relu'))
model.add(ly.Dense(units=12, activation='relu'))
model.add(ly.Dense(units=6, activation='relu'))
model.add(ly.Dense(units=1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
vis.main(model, data_generators.cluster_generator, 'accuracy',n_points=3000, cluster_width=50, p_train=10, window=50, write=True)

# %%
import time

# %%
# !open ~/Documents/Projecten/JADS/olac/olac/olac/__init__.py

# %%
plt.plot(np.arange(0,10))
plt.savefig('tmp/test.png')

# %%
# !open .

# %%
images = []
for i, filename in enumerate(os.listdir('tmp')):
    filename = 'tmp/'+str(i)+'.png'
    images.append(imageio.imread(filename))
    imageio.mimsave('progressgif'+time.strftime('%Y-%m-%d', time.localtime(time.time()))+'.gif', images)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f2ece8ec07b9> in <module>()
#       1 images = []
# ----> 2 for i in np.arange(1, itrs, int(window/4)):
#       3     filename = 'tmp/'+str(i)+'.png'
#       4     images.append(imageio.imread(filename))
#       5     imageio.mimsave('progressgif'+time.strftime('%Y-%m-%d', time.localtime(time.time()))+'.gif', images)
#
# NameError: name 'itrs' is not defined

# %%
import os

# %%
files = os.listdir('tmp')[1:]

# %%
files2 = [int(a.split('.')[0]) for a in files]

# %%
files2.sort()

# %%
import imageio
import time
import tqdm
images = []
for filename in tqdm.tqdm(files2):
    filename = 'tmp/'+str(filename)+'.png'
    images.append(imageio.imread(filename))
    imageio.mimsave('progressgif'+time.strftime('%Y-%m-%d', time.localtime(time.time()))+'.gif', images)
# Out:
# 100%|██████████| 167/167 [21:06<00:00,  7.58s/it]
